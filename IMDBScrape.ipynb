# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import requests
from bs4 import BeautifulSoup
from IPython.core.display import HTML
from html.parser import HTMLParser
import re
import io
from PIL import Image
from pathlib import Path
import hashlib

# %%
URL = 'https://www.imdb.com/list/ls033398199/?sort=user_rating,desc&st_dt=&mode=detail&page=1'
response = requests.get(URL)
soup = BeautifulSoup(response.text)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    var IMDbTimer={starttime: new Date().getTime(),pt:'java'};
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <title>
#    Highest-Rated Anime Series on IMDb - IMDb
#   </title>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
#   </script>
# ...

# %%
titles = soup.findAll('h3')[0:60]
title_list = [x.find('a').text for x in titles]

# %%
dates = soup.findAll('h3')[0:60]
date_list = [x.find('span', attrs={'class' : 'lister-item-year text-muted unbold'}).text for x in dates]

# %%
ratings = soup.findAll('span', attrs={'class' : 'certificate'})[0:60]
ratings_list = [x.text for x in ratings]

# %%
genre = soup.findAll('span', attrs={'class' : 'genre'})[0:60]
genre_list = [x.text.split() for x in genre]

# %%
stars = soup.findAll('span', attrs={'class' : 'ipl-rating-star__rating'})[0::23]
stars_list = [x.text for x in stars]

# %%
starring = soup.findAll('p')
starring_list1 = [x.text.split() for x in starring][3:103:5]

# %%
starring_list2 = [x.text.split() for x in starring][102:132:5]

# %%
starring_list3 = [x.text.split() for x in starring][131:137:5]

# %%
starring_list4 = [x.text.split() for x in starring][140:141]

# %%
starring_list5 = [x.text.split() for x in starring][145:157:4]

# %%
starring_list6 = [x.text.split() for x in starring][158:168:5]

# %%
starring_list7 = [x.text.split() for x in starring][167:177:5]

# %%
starring_list8 = [x.text.split() for x in starring][176:300:4]

# %%
starring_list = (starring_list1 + starring_list2 + starring_list3 + starring_list4 + starring_list5 + starring_list6 + starring_list7 + starring_list8)

# %%
lister_item = soup.findAll('div', attrs={'class' : 'lister-item'})

# %%
x = lister_item[0].find('div', attrs={'class' : 'list-description'})

# %%
if x : 
    print(x)
# Out:
# <div class="list-description"><p>#69 on Top 250</p></div>

# %%
y = lister_item[19].find('div', attrs={'class' : 'list-description'})

# %%
if y :
    print(y)
else : 
    print('none')
# Out:
# <div class="list-description"><p>#110 on Top 250</p></div>

# %%
item_list = []
for item in lister_item : 
    if item.find('div', attrs= {'class' : 'list-description'}):
        item_list.append(item.find('div', attrs={'class' : 'list-description'}).text)
    else :
        item_list.append('not top 250')

# %%
total_votes = soup.findAll('p')
vote_count1 = [x.text.strip() for x in total_votes][4:100:5]

# %%
vote_count2 = [x.text.strip() for x in total_votes][103:130:5]

# %%
vote_count3 = [x.text.strip() for x in total_votes][132:140:5]

# %%
vote_count4 = [x.text.strip() for x in total_votes][141:147:5]

# %%
vote_count5 = [x.text.strip() for x in total_votes][150:155:4]

# %%
vote_count6 = [x.text.strip() for x in total_votes][159:165:5]

# %%
vote_count7 = [x.text.strip() for x in total_votes][168:169]

# %%
vote_count8 = [x.text.strip() for x in total_votes][173:300:4]

# %%
vote_counts = (vote_count1 + vote_count2 + vote_count3 + vote_count4 + vote_count5 + vote_count6 + vote_count7 + vote_count8)

# %% [markdown]
# Try Selenium later if i can for full vote counts

# %%
desc1 = soup.findAll('p')[2:95:5]
d1 = [x.text.strip() for x in desc1]
desc2 = soup.findAll('p')[96:130:5]
d2 = [x.text.strip() for x in desc2]
desc3 = soup.findAll('p')[130:140:5]
d3 = [x.text.strip() for x in desc3]
desc4 = soup.findAll('p')[139:145:5]
d4 = [x.text.strip() for x in desc4]
desc5 = soup.findAll('p')[148]
d5 = [x.text.strip() for x in desc5]
desc6 = soup.findAll('p')[152:165:5]
d6 = [x.text.strip() for x in desc6]
desc7 = soup.findAll('p')[166:172:5]
d7 = [x.text.strip() for x in desc7]
desc8 = soup.findAll('p')[175:300:4]
d8 = [x.text.strip() for x in desc8]

# %%
descriptions = (d1 + d2 + d3+ d4 + d5 + d6 + d7 + d8)

# %%
top_anime = {'Title' : title_list, 'Genres' : genre_list, 'Run Dates' : date_list, 'Rating' : ratings_list, 'Stars' : stars_list, 'Votes' : vote_counts, 'Actors' : starring_list, 'Top 250 TV' : item_list, 'Descriptions' : descriptions}
top_anime = pd.DataFrame(top_anime)

# %%
top_anime.index = top_anime.index + 1
top_anime = top_anime.reset_index()
top_anime = top_anime.rename(columns = {'index' : 'Rank'})

# %%
top_anime['Votes'] = top_anime['Votes'].str[7:]

# %%
top_anime['Actors'] = top_anime['Actors'].str[1:]

# %%
top_anime['Actors'] = top_anime['Actors'].apply(lambda x: ', '.join(x).replace(', ', ' ').replace(',,', ',,').split(','))

# %%
links = soup.findAll('h3')[0:60]
page_link = [x.find('a') for x in links]

# %%
urls = [link['href'] for link in page_link]
full_urls = ['https://www.imdb.com' + url for url in urls]

# %%
image = soup.findAll('img')[0:300:2]
images = [x.get('src') for x in image]

# %%
# images_df = pd.DataFrame({'Linkes': images})
# images_df.to_csv(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone\imagelink.csv', index=False, encoding = 'utf-8)')

# %%
# for b in images:
#     image_content = requests.get(b).content

# %%
# image_file = io.BytesIO(image_content)

# %%
# image5 = Image.open(image_file).convert("RGB")

# %%
# file_path = Path(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone/Image Coded', hashlib.sha1(image_content).hexdigest()[:10] + '.png')
# image5.save(file_path, 'PNG', quality = 80)

# %%
top_anime['Links'] = full_urls

# %%
top_anime.head(1)
# Out:
#    Rank            Title                            Genres    Run Dates  \
# 0     1  Attack on Titan  [Animation,, Action,, Adventure]  (2013–2023)
#
#   Rating Stars    Votes                                             Actors  \
# 0  TV-MA   9.1  509,439  [Jessie James Grelle,  Bryce Papenbrook,  Trin...
#
#        Top 250 TV                                       Descriptions  \
# 0  #69 on Top 250  After his hometown is destroyed and is traumat...
#
#                                    Links
# 0  https://www.imdb.com/title/tt2560140/

# %%
pd.set_option('display.max_columns', None)

# %%
kaggle = pd.read_csv('../NSS_Capstone/anime.csv.csv')
kaggle.columns
# Out:
# Index(['MAL_ID', 'Name', 'Score', 'Genres', 'English name', 'Japanese name',
#        'Type', 'Episodes', 'Aired', 'Premiered', 'Producers', 'Licensors',
#        'Studios', 'Source', 'Duration', 'Rating', 'Ranked', 'Popularity',
#        'Members', 'Favorites', 'Watching', 'Completed', 'On-Hold', 'Dropped',
#        'Plan to Watch', 'Score-10', 'Score-9', 'Score-8', 'Score-7', 'Score-6',
#        'Score-5', 'Score-4', 'Score-3', 'Score-2', 'Score-1'],
#       dtype='object')

# %%
kaggle= kaggle[['Name', 'English name', 'Score', 'Genres', 'Episodes', 'Aired', 'Premiered', 'Producers', 'Licensors', 'Studios', 'Score-10', 'Score-9', 'Score-8', 'Score-7', 'Score-6', 'Score-5', 'Score-4', 'Score-3', 'Score-2', 'Score-1']]

# %%
kaggle = kaggle.rename(columns = {'English name' : 'Title'})
kaggle.head()
# Out:
#                               Name                   Title Score  \
# 0                     Cowboy Bebop            Cowboy Bebop  8.78
# 1  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop:The Movie  8.39
# 2                           Trigun                  Trigun  8.24
# 3               Witch Hunter Robin      Witch Hunter Robin  7.27
# 4                   Bouken Ou Beet  Beet the Vandel Buster  6.98
#
#                                               Genres Episodes  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space       26
# 1              Action, Drama, Mystery, Sci-Fi, Space        1
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen       26
# 3  Action, Mystery, Police, Supernatural, Drama, ...       26
# 4          Adventure, Fantasy, Shounen, Supernatural       52
#
#                           Aired    Premiered  \
# 0   Apr 3, 1998 to Apr 24, 1999  Spring 1998
# 1                   Sep 1, 2001      Unknown
# 2   Apr 1, 1998 to Sep 30, 1998  Spring 1998
# ...

# %%
fullmetal = kaggle.loc[kaggle['Title'].str.contains('Fullmetal Alchemist:Brotherhood')].head(1)
fullmetal['Title'] = fullmetal.Title.str.replace('Alchemist:Brotherhood', 'Alchemist: Brotherhood')
kaggle = pd.concat([kaggle, fullmetal])

# %%
naruto = kaggle.loc[kaggle['Title'].str.contains('Naruto:Shippuden')].head(1)
naruto['Title'] = naruto.Title.str.replace('Naruto:Shippuden', 'Naruto: Shippuden')
kaggle = pd.concat([kaggle, naruto])

# %%
code = kaggle.loc[kaggle['Title'].str.contains('Code Geass')].head(1)
code['Title'] = code.Title.str.replace('Code Geass:Lelouch of the Rebellion', 'Code Geass')
kaggle = pd.concat([kaggle, code])

# %%
rurouni = kaggle.loc[kaggle.Title.str.contains('Rurouni')].head(1)
rurouni['Title'] = rurouni.Title.str.replace('Rurouni Kenshin', 'Rurouni Kenshin: Trust and Betrayal')
kaggle = pd.concat([kaggle, rurouni])

# %%
yuyu = kaggle.loc[kaggle.Title.str.contains('Hakusho')].head(1)
yuyu['Title'] = yuyu.Title.str.replace('Yu Yu Hakusho:Ghost Files', 'Yu Yu Hakusho: Ghost Files')
kaggle = pd.concat([kaggle, yuyu])

# %% [markdown]
# Drop Detective Conan

# %%
ghost = kaggle.loc[kaggle.Title.str.contains('Ghost in the Shell:Stand')].head(1)
ghost['Title'] = ghost.Title.str.replace('Ghost in the Shell:Stand Alone Complex', 'Ghost in the Shell: Stand Alone Complex')
kaggle = pd.concat([kaggle, ghost])

# %%
parasyte = kaggle.loc[kaggle.Title.str.contains('Parasyte')]
parasyte['Title'] = parasyte.Title.str.replace ('Parasyte -the maxim-', 'Parasyte: The Maxim')
kaggle = pd.concat([kaggle, parasyte])
kaggle.tail(1)
# Out:
# C:\Users\shane\AppData\Local\Temp\ipykernel_31516\310978695.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parasyte['Title'] = parasyte.Title.str.replace ('Parasyte -the maxim-', 'Parasyte: The Maxim')
#                             Name                Title Score  \
# 8704  Kiseijuu: Sei no Kakuritsu  Parasyte: The Maxim   8.4
#
#                                                  Genres Episodes  \
# 8704  Action, Sci-Fi, Horror, Psychological, Drama, ...       24
#
#                             Aired  Premiered  \
# 8704  Oct 9, 2014 to Mar 26, 2015  Fall 2014
#
#                                               Producers         Licensors  \
# 8704  VAP, Kodansha, Nippon Television Network, Fore...  Sentai Filmworks
#
# ...

# %%
inu = kaggle.loc[kaggle.Title.str.contains('Inu')].head(1)
inu['Title'] = inu.Title.str.replace('InuYasha', 'Inuyasha')
kaggle = pd.concat([kaggle, inu])

# %%
dark = kaggle.loc[kaggle.Title.str.contains('Darker')].head(1)
dark['Title'] = dark.Title.str.replace('Darker than Black', 'Darker Than Black')
kaggle = pd.concat([kaggle, dark])

# %%
kaggle.loc[kaggle.Title.str.contains('Detective')]
# Out:
#                                                     Name  \
# 220        Agatha Christie no Meitantei Poirot to Marple
# 311                               Matantei Loki Ragnarok
# 383                                      Tantei Gakuen Q
# 584                     Night Walker: Mayonaka no Tantei
# 1680                              Clamp Gakuen Tanteidan
# 1877                                   Ojousama Sousamou
# 2087                             Jikuu Tantei Genshi-kun
# 2488                            Kaiketsu Jouki Tanteidan
# 2508                                        Sukeban Deka
# 2707                             Suteki Tantei Labyrinth
# 2723                          Majin Tantei Nougami Neuro
# 3958                           Fabre-sensei wa Meitantei
# 4140          Detective Conan Movie 13: The Raven Chaser
# 4416                            Megami Tantei Vinus File
# 4460                     Aruhi no Clamp Gakuen Tanteidan
# ...

# %%
anime = top_anime.merge(kaggle, how='left', on='Title')
anime.columns
# Out:
# Index(['Rank', 'Title', 'Genres_x', 'Run Dates', 'Rating', 'Stars', 'Votes',
#        'Actors', 'Top 250 TV', 'Descriptions', 'Links', 'Name', 'Score',
#        'Genres_y', 'Episodes', 'Aired', 'Premiered', 'Producers', 'Licensors',
#        'Studios', 'Score-10', 'Score-9', 'Score-8', 'Score-7', 'Score-6',
#        'Score-5', 'Score-4', 'Score-3', 'Score-2', 'Score-1'],
#       dtype='object')

# %%
anime = anime[['Rank', 'Title', 'Rating', 'Stars', 'Episodes', 'Votes', 'Actors', 'Top 250 TV', 'Descriptions', 'Name', 'Genres_y', 'Aired', 'Producers', 'Licensors', 'Studios', 'Score-10', 'Score-9', 'Score-8', 'Score-7', 'Score-6', 'Score-5', 'Score-4', 'Score-3', 'Score-2', 'Score-1']]

# %%
anime = anime.rename(columns = {'Genres_y' : 'Genres'})

# %%
anime.Rating.value_counts()
# Out:
# Rating
# TV-14        31
# TV-MA        21
# TV-PG         8
# Not Rated     1
# TV-Y          1
# Name: count, dtype: int64

# %%
anime = anime.loc[~anime.Title.isin(['Detective Conan'])]
anime.head(60)
# Out:
#     Rank                                    Title     Rating Stars Episodes  \
# 0      1                          Attack on Titan      TV-MA   9.1       25
# 1      2         Fullmetal Alchemist: Brotherhood      TV-14   9.1       64
# 2      3                                One Piece      TV-14     9  Unknown
# 3      4                          Hunter x Hunter      TV-14     9       62
# 4      4                          Hunter x Hunter      TV-14     9      148
# 5      5                               Death Note      TV-14   8.9       37
# 6      6                             Cowboy Bebop      TV-14   8.9       26
# 7      7                            Dragon Ball Z      TV-PG   8.8      291
# 8      8                              Steins;Gate      TV-14   8.8       24
# 9      9                            Dragon Ball Z      TV-PG   8.8      291
# 10    10                        Naruto: Shippuden      TV-PG   8.7      500
# ...

# %%
anime = anime.drop([anime.index[3], anime.index[11]])
anime = anime.set_index('Rank')
anime = anime.reset_index()

# %%
pd.set_option("max_colwidth", None)

# %%
anime.head()
# Out:
#    Rank                             Title Rating Stars Episodes    Votes  \
# 0     1                   Attack on Titan  TV-MA   9.1       25  509,439
# 1     2  Fullmetal Alchemist: Brotherhood  TV-14   9.1       64  197,157
# 2     3                         One Piece  TV-14     9  Unknown  234,089
# 3     4                   Hunter x Hunter  TV-14     9      148  134,293
# 4     5                        Death Note  TV-14   8.9       37  377,837
#
#                                                                    Actors  \
# 0  [Jessie James Grelle,  Bryce Papenbrook,  Trina Nishimura,  Yûki Kaji]
# 1       [Kent Williams,  Iemasa Kayumi,  Matthew Leonhart,  Vic Mignogna]
# 2            [Mayumi Tanaka,  Akemi Okamura,  Laurent Vernin,  Tony Beck]
# 3        [Issei Futamata,  Megumi Han,  Cristina Valenzuela,  Mariya Ise]
# 4                [Mamoru Miyano,  Brad Swaile,  Vincent Tong,  Ryô Naitô]
#
#         Top 250 TV  \
# 0   #69 on Top 250
# 1   #23 on Top 250
# ...

# %%
horror = anime.loc[anime.Genres.str.contains('Horror')]

# %%
fantasy = anime.loc[anime.Genres.str.contains('Fantasy')]

# %%
drama = anime.loc[anime.Genres.str.contains('Drama')]

# %%
magic = anime.loc[anime.Genres.str.contains('Magic')]

# %%
adventure = anime.loc[anime.Genres.str.contains('Adventure')]

# %%
supernatural = anime.loc[anime.Genres.str.contains('Supernatural')]

# %%
comedy = anime.loc[anime.Genres.str.contains('Comedy')]

# %%
scifi = anime.loc[anime.Genres.str.contains('Sci-Fi')]

# %%
martialarts = anime.loc[anime.Genres.str.contains('Martial Arts')]

# %%
romance = anime.loc[anime.Genres.str.contains('Romance')]

# %%
parody = anime.loc[anime.Genres.str.contains('Parody')]

# %%
psychological = anime.loc[anime.Genres.str.contains('Psychological')]

# %%
military = anime.loc[anime.Genres.str.contains('Military')]

# %%
mystery = anime.loc[anime.Genres.str.contains('Mystery')]

# %%
action = anime.loc[anime.Genres.str.contains('Action')]

# %%
horror.to_csv(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone\horror.csv')

# %%
fantasy.to_csv(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone\fantasy.csv')
drama.to_csv(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone\drama.csv')
magic.to_csv(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone\magic.csv')
adventure.to_csv(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone\adventure.csv')
supernatural.to_csv(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone\supernatural.csv')
comedy.to_csv(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone\comedy.csv')
scifi.to_csv(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone\.scifi.csv')
martialarts.to_csv(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone\martialarts.csv')
romance.to_csv(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone\romance.csv')
parody.to_csv(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone\parody.csv')
psychological.to_csv(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone\pyschological.csv')
military.to_csv(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone\military.csv')
mystery.to_csv(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone\mystery.csv')
action.to_csv(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone\action.csv')

# %%
anime.to_csv(r'C:\Users\shane\Documents\Data Analyst School\NSS_Capstone\top_anime.csv')

# %%
anime['Episodes'] = anime.Episodes.str.replace('Unknown', '1000+')

# %%
anime.head(10)
# Out:
#    Rank                             Title Rating Stars Episodes    Votes  \
# 0     1                   Attack on Titan  TV-MA   9.1       25  509,439
# 1     2  Fullmetal Alchemist: Brotherhood  TV-14   9.1       64  197,157
# 2     3                         One Piece  TV-14     9    1000+  234,089
# 3     4                   Hunter x Hunter  TV-14     9      148  134,293
# 4     5                        Death Note  TV-14   8.9       37  377,837
# 5     6                      Cowboy Bebop  TV-14   8.9       26  138,633
# 6     7                     Dragon Ball Z  TV-PG   8.8      291  147,506
# 7     8                       Steins;Gate  TV-14   8.8       24   73,279
# 8     9                     Dragon Ball Z  TV-PG   8.8      291   87,709
# 9    10                 Naruto: Shippuden  TV-PG   8.7      500  168,115
#
#                                                                    Actors  \
# 0  [Jessie James Grelle,  Bryce Papenbrook,  Trina Nishimura,  Yûki Kaji]
# ...

# %%
romance
# Out:
#     Rank                                Title Rating Stars Episodes   Votes  \
# 10    11                              Berserk  TV-MA   8.7       12  52,950
# 14    15  Rurouni Kenshin: Trust and Betrayal  TV-MA   8.6       94  16,179
# 21    23                      Rurouni Kenshin  TV-14   8.5       94  20,547
# 32    34          Ouran High School Host Club  TV-14   8.2       26  11,617
# 40    42                           Elfen Lied  TV-MA   7.9       13  36,872
# 42    44                             Inuyasha  TV-14   7.9      167  17,901
# 53    55                          Sailor Moon   TV-Y   7.6       46  13,172
# 55    57                     Sword Art Online  TV-14   7.5       25  52,586
#
#                                                                        Actors  \
# 10      [Marc Diraison,  Nobutoshi Canna,  Carrie Keranen,  Kevin T. Collins]
# 14               [Mayo Suzukaze,  Junko Iwao,  Nozomu Sasaki,  Masami Suzuki]
# ...

# %%
anime.head(25)
# Out:
#     Rank                                    Title Rating Stars Episodes  \
# 0      1                          Attack on Titan  TV-MA   9.1       25
# 1      2         Fullmetal Alchemist: Brotherhood  TV-14   9.1       64
# 2      3                                One Piece  TV-14     9    1000+
# 3      4                          Hunter x Hunter  TV-14     9      148
# 4      5                               Death Note  TV-14   8.9       37
# 5      6                             Cowboy Bebop  TV-14   8.9       26
# 6      7                            Dragon Ball Z  TV-PG   8.8      291
# 7      8                              Steins;Gate  TV-14   8.8       24
# 8      9                            Dragon Ball Z  TV-PG   8.8      291
# 9     10                        Naruto: Shippuden  TV-PG   8.7      500
# 10    11                                  Berserk  TV-MA   8.7       12
# 11    12                            One Punch Man  TV-PG   8.7       12
# ...
