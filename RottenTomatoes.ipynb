# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import requests
from bs4 import BeautifulSoup
from IPython.core.display import HTML
from html.parser import HTMLParser
import re

# %%
URL = 'https://www.rottentomatoes.com/browse/tv_series_browse/genres:anime~sort:popular'
response = requests.get(URL)
soup = BeautifulSoup(response.text)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="fb: http://www.facebook.com/2008/fbml og: http://opengraphprotocol.org/schema/" xmlns="http://www.w3.org/1999/xhtml">
#  <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
#   <script charset="UTF-8" crossorigin="anonymous" data-domain-script="7e979733-6841-4fce-9182-515fac69187f" integrity="sha384-TKdmlzVmoD70HzftTw4WtOzIBL5mNx8mXSRzEvwrWjpIJ7FZ/EuX758yMDWXtRUN" src="https://cdn.cookielaw.org/consent/7e979733-6841-4fce-9182-515fac69187f/otSDKStub.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    function OptanonWrapper() { }
#   </script>
#   <script ccpa-opt-out-geo="US" ccpa-opt-out-ids="USP" ccpa-opt-out-lspa="false" charset="UTF-8" src="https://cdn.cookielaw.org/opt-out/otCCPAiab.js" type="text/javascript">
#   </script>
#   <script src="/assets/pizza-pie/javascripts/bundles/roma/rt-common.js?single">
#   </script>
# ...

# %%
title = soup.findAll('span', attrs={'class' : 'p--small'})[4:28]
titles = [x.text.strip() for x in title]

# %%
audience = soup.findAll('score-pairs-deprecated')
audiences = [x for x in audience]
audiences
# Out:
# [<score-pairs-deprecated audiencescore="100" audiencesentiment="positive" criticsscore="" criticssentiment="">
#  </score-pairs-deprecated>,
#  <score-pairs-deprecated audiencescore="94" audiencesentiment="positive" criticsscore="100" criticssentiment="positive">
#  </score-pairs-deprecated>,
#  <score-pairs-deprecated audiencescore="91" audiencesentiment="positive" criticsscore="" criticssentiment="">
#  </score-pairs-deprecated>,
#  <score-pairs-deprecated audiencescore="90" audiencesentiment="positive" criticsscore="" criticssentiment="">
#  </score-pairs-deprecated>,
#  <score-pairs-deprecated audiencescore="94" audiencesentiment="positive" criticsscore="95" criticssentiment="positive">
#  </score-pairs-deprecated>,
#  <score-pairs-deprecated audiencescore="91" audiencesentiment="positive" criticsscore="100" criticssentiment="positive">
#  </score-pairs-deprecated>,
#  <score-pairs-deprecated audiencescore="" audiencesentiment="" criticsscore="" criticssentiment="">
# ...
